# %% [markdown]
# <a href="https://colab.research.google.com/github/komorimasashi/bunka-hakaru/blob/main/r_network_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("igraph")
library(igraph)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %% [markdown]
# 語のベクトルを作成します

# %%
script <- c(
  "アタシ",
  "アキ",
  "歳？",
  "23",
  "まぁ今年で２４",
  "彼氏？",
  "まぁ",
  "当たり前に",
  "いる",
  "てか",
  "いない訳ないじゃん",
  "みたいな",
  "彼氏は",
  "普通",
  "てか",
  "アタシが付き合って",
  "あげてる",
  "みたいな",
  "付き合って５ヶ月",
  "彼氏の名前",
  "トモ",
  "歳？",
  "３１歳",
  "多分",
  "顔？",
  "まぁ普通",
  "人より目はデカイかな？",
  "性格？",
  "まぁ普通",
  "アタシが",
  "変な男と",
  "付き合う訳ないし",
  "みたいな")

# %% [markdown]
# 隣り合った単語の組み合わせを作成します

# %%
cooccurrence <- cbind(script[1:(length(script)-1)], script[2:length(script)])
print(cooccurrence)
# Out:
#       [,1]                     [,2]
#  [1,] "アタシ"                 "アキ"
#  [2,] "アキ"                   "歳？"
#  [3,] "歳？"                   "23"
#  [4,] "23"                     "まぁ今年で２４"
#  [5,] "まぁ今年で２４"         "彼氏？"
#  [6,] "彼氏？"                 "まぁ"
#  [7,] "まぁ"                   "当たり前に"
#  [8,] "当たり前に"             "いる"
#  [9,] "いる"                   "てか"
# [10,] "てか"                   "いない訳ないじゃん"
# [11,] "いない訳ないじゃん"     "みたいな"
# [12,] "みたいな"               "彼氏は"
# [13,] "彼氏は"                 "普通"
# [14,] "普通"                   "てか"
# [15,] "てか"                   "アタシが付き合って"
# [16,] "アタシが付き合って"     "あげてる"
# [17,] "あげてる"               "みたいな"
# [18,] "みたいな"               "付き合って５ヶ月"
# [19,] "付き合って５ヶ月"       "彼氏の名前"
# [20,] "彼氏の名前"             "トモ"
# [21,] "トモ"                   "歳？"
# [22,] "歳？"                   "３１歳"
# [23,] "３１歳"                 "多分"
# [24,] "多分"                   "顔？"
# [25,] "顔？"                   "まぁ普通"
# [26,] "まぁ普通"               "人より目はデカイかな？"
# ...

# %% [markdown]
# グラフを作成します

# %%
wng<-graph.data.frame(cooccurrence) 
plot(wng,vertex.label=V(wng)$name, layout=layout.fruchterman.reingold,vertex.size=1)
# Out:
# Plot with title “”
